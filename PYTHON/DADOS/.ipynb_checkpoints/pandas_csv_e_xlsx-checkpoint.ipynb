# %%
from google.colab import drive
import pandas as pd
from pathlib import Path

# %%
from google.colab import drive
drive.mount('/content/drive')
arquivo = Path('/content/spotify_data.csv')

df = pd.DataFrame()

if  arquivo.exists():
  df = pd.read_csv(arquivo)

  print('Arquivo carregado com sucesso')
else:
  print(f'Erro: O arquivo {arquivo} não foi encontrado')

try:
    df = pd.read_csv(arquivo)
    print('Dados lidos com sucesso')
    print(df.head)
    print(df.describe()) # statistic -> campos numericos
    print(df.columns)
    print(df['Ano'])

except FileNotFoundError:
  print('O arquivo de Excel não existe. Verifique')
except Exception as e:
  print(f"Ocorreu um erro inesperado {e}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Arquivo carregado com sucesso
# Dados lidos com sucesso
# <bound method NDFrame.head of               Musica        Artista     Streams   Ano
# 0    Blinding Lights     The Weeknd  3400000000  2019
# 1       Shape of You     Ed Sheeran  3300000000  2017
# 2  Someone You Loved  Lewis Capaldi  2600000000  2018
# 3            Starboy     The Weeknd  2500000000  2016
# 4          One Dance          Drake  2500000000  2016>
#             Streams         Ano
# count  5.000000e+00     5.00000
# mean   2.860000e+09  2017.20000
# std    4.505552e+08     1.30384
# min    2.500000e+09  2016.00000
# 25%    2.500000e+09  2016.00000
# 50%    2.600000e+09  2017.00000
# 75%    3.300000e+09  2018.00000
# max    3.400000e+09  2019.00000
# Index(['Musica', 'Artista', 'Streams', 'Ano'], dtype='object')
# 0    2019
# 1    2017
# 2    2018
# 3    2016
# 4    2016
# Name: Ano, dtype: int64

# %% [markdown]
# XLSX

# %%
arquivo2 = Path('/content/inventario_vendas.xlsx')

try:
  df_excel = pd.read_excel(arquivo2)
  df_excel['Valor_Total'] = df_excel['Preco'] * df_excel['Estoque']
  df_excel['Valor_Desconto'] = df_excel['Valor_Total'] * [0.1]

  df_ordenado = df_excel.sort_values(by='Preco', ascending=True)

  print(df_excel)

  if df_excel['Valor_Total'].max() > 1000:
    print('Existem produtos com valor total acima de R$1000. ')

  if df_excel['Valor_Desconto'].max() > 10:
    print('Existem produtos com valor de desconto acima de R$ 100.')

  acima_de_20 = df_excel[df_excel['Estoque'] > 20]
  print(acima_de_20)

  """ Criando um novo arquivo EXCEL(xlsx) """
  #df_excel.to_excel('novo_inventario.xlsx', index=False)

except FileNotFoundError:
  print('o arquivo de Excel não existe. Verifique o nome e /caminho')
except Exception as i:
  print(f"Ocorreu um erro inesperado: {i}")
# Out:
#             Produto  Preco  Estoque    Categoria  Valor_Total  Valor_Desconto
# 0        Smartphone   2500       15  Eletrônicos        37500          3750.0
# 1        Monitor 4K   1800        8  Periféricos        14400          1440.0
# 2  Teclado Mecânico    450       25  Periféricos        11250          1125.0
# 3    Mouse Wireless    120       40   Acessórios         4800           480.0
# 4     Headset Gamer    350       20        Áudio         7000           700.0
# Existem produtos com valor total acima de R$1000.
# Existem produtos com valor de desconto acima de R$ 100.
#             Produto  Preco  Estoque    Categoria  Valor_Total  Valor_Desconto
# 2  Teclado Mecânico    450       25  Periféricos        11250          1125.0
# 3    Mouse Wireless    120       40   Acessórios         4800           480.0
